# %%
# import the packages 
# read the data visadata
# cat num columns quickly

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\DELL\Naresh It\Data_files\Visadataset.csv")

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df
visa_df.dtypes
cat=[]
num=[]
keys=visa_df.dtypes.keys()
value=visa_df.dtypes.values
for i,j in zip(keys,value):
    if j =='object':
        cat.append(i)
    else:
        num.append(i)
print(cat,num)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status'] ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# **Select_dtypes**

# %%
cat=visa_df.select_dtypes(include="object").columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
cat,num
# Out:
# (Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#         'requires_job_training', 'region_of_employment', 'unit_of_wage',
#         'full_time_position', 'case_status'],
#        dtype='object'),
#  Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object'))

# %% [markdown]
# **Categorical column analysis**

# %%
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df[['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df.continent
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.iloc[:,1]
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.iloc[:,[1]]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df.loc[:,'continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.loc[:,['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df  #Df
visa_df['continent']   #series
visa_df['continent'].values  # raw data
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %% [markdown]
# **Continent**

# %%
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
visa_df['continent'].nunique()
# Out:
# 6

# %% [markdown]
# **Frequency Tables**

# %%
con=visa_df['continent']=='Asia'
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
len(visa_df[con])
# Out:
# 16861

# %%
print(np.sum(con))
# Out:
# 16861

# %%
count=[]
for i in visa_df['continent'].unique():
    con=visa_df['continent']==i
    count.append(np.sum(con))
count
# Out:
# [np.int64(16861),
#  np.int64(551),
#  np.int64(3292),
#  np.int64(3732),
#  np.int64(852),
#  np.int64(192)]

# %%
for i in visa_df['continent'].unique():
    con=visa_df['continent']==i
    S=np.sum(con)
    print(f"{i} = {S}")
# Out:
# Asia = 16861
# Africa = 551
# North America = 3292
# Europe = 3732
# South America = 852
# Oceania = 192

# %%
cont=visa_df['continent'].unique()
cont
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
count
# Out:
# [np.int64(16861),
#  np.int64(551),
#  np.int64(3292),
#  np.int64(3732),
#  np.int64(852),
#  np.int64(192)]

# %%
df1=pd.DataFrame(zip(cont,count),
columns=['Continent','No of Application'])

# %%
df1.to_csv('continent_df.csv',index=False)

# %%
df1
# Out:
#        Continent  No of Application
# 0           Asia              16861
# 1         Africa                551
# 2  North America               3292
# 3         Europe               3732
# 4  South America                852
# 5        Oceania                192

# %% [markdown]
# **Value Count**

# %%
visa_df
visa_df['continent']
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df
visa_df['continent']
visa_df['continent'].values
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %%
visa_df['continent'].value_counts(normalize=True)
# Out:
# continent
# Asia             0.661735
# Europe           0.146468
# North America    0.129199
# South America    0.033438
# Africa           0.021625
# Oceania          0.007535
# Name: proportion, dtype: float64

# %%
visa_df['continent'].value_counts(normalize=True)*100
# Out:
# continent
# Asia             66.173469
# Europe           14.646782
# North America    12.919937
# South America     3.343799
# Africa            2.162480
# Oceania           0.753532
# Name: proportion, dtype: float64

# %% [markdown]
# **Bar Chat**

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values

# %%
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
values
# Out:
# array([16861,  3732,  3292,   852,   551,   192])

# %%
plt.bar
plt.pie

# %%
plt.bar(keys,values)
# Out:
# <BarContainer object of 6 artists>

# %%
dir(plt)
# Out:
# ['AbstractContextManager',
#  'Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'AxLine',
#  'Axes',
#  'BackendFilter',
#  'Button',
#  'Circle',
#  'Colorizer',
#  'ColorizingArtist',
#  'Colormap',
#  'Enum',
#  'ExitStack',
#  'Figure',
#  'FigureBase',
#  'FigureCanvasBase',
#  'FigureManagerBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MouseButton',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotSpec',
#  'TYPE_CHECKING',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_ColorizerInterface',
#  '_NO_PYPLOT_NOTE',
#  '_REPL_DISPLAYHOOK',
#  '_ReplDisplayHook',
#  '__annotations__',
# ...

# %%
plt.figure(figsize=(10, 6))
plt.bar(keys,values)
# plt.show()
plt.xlabel('Continents')
plt.ylabel('No of Applicants')
plt.title('Continent_bar_chart')
plt.savefig('continent.jpg')

# %%
plt.figure(figsize=(10, 6))
colours=['Green','Blue','yellow','black','red','purple']
plt.bar(keys,values,color=colours)
plt.xlabel('Continents')
plt.ylabel('No of Applicants')
plt.title('Continent_bar_chart')
plt.savefig('continent.jpg')
plt.show()

# %%
from matplotlib import colors

# %%
colors.CSS4_COLORS
# Out:
# {'aliceblue': '#F0F8FF',
#  'antiquewhite': '#FAEBD7',
#  'aqua': '#00FFFF',
#  'aquamarine': '#7FFFD4',
#  'azure': '#F0FFFF',
#  'beige': '#F5F5DC',
#  'bisque': '#FFE4C4',
#  'black': '#000000',
#  'blanchedalmond': '#FFEBCD',
#  'blue': '#0000FF',
#  'blueviolet': '#8A2BE2',
#  'brown': '#A52A2A',
#  'burlywood': '#DEB887',
#  'cadetblue': '#5F9EA0',
#  'chartreuse': '#7FFF00',
#  'chocolate': '#D2691E',
#  'coral': '#FF7F50',
#  'cornflowerblue': '#6495ED',
#  'cornsilk': '#FFF8DC',
#  'crimson': '#DC143C',
#  'cyan': '#00FFFF',
#  'darkblue': '#00008B',
#  'darkcyan': '#008B8B',
#  'darkgoldenrod': '#B8860B',
#  'darkgray': '#A9A9A9',
#  'darkgreen': '#006400',
#  'darkgrey': '#A9A9A9',
#  'darkkhaki': '#BDB76B',
#  'darkmagenta': '#8B008B',
#  'darkolivegreen': '#556B2F',
#  'darkorange': '#FF8C00',
#  'darkorchid': '#9932CC',
#  'darkred': '#8B0000',
#  'darksalmon': '#E9967A',
#  'darkseagreen': '#8FBC8F',
#  'darkslateblue': '#483D8B',
#  'darkslategray': '#2F4F4F',
# ...

# %%
for i in cat[1:]:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    plt.figure(figsize=(10, 6))
    plt.bar(keys,values)
    plt.xlabel('Lables')
    plt.ylabel('Counts')
    plt.title(f'{i}_bar_chart')
    plt.savefig(f'{i}.jpg')
    plt.show()

# %%
import random
for i in cat[1:]:
    
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    plt.figure(figsize=(10, 6))
    plt.bar(keys,values)
    plt.xlabel('Lables')
    plt.ylabel('Counts')
    plt.title(f'{i}_bar_chart')
    plt.savefig(f'{i}.jpg')
    plt.show()

# %%
plt.pie(values,labels=keys)
# Out:
# ([<matplotlib.patches.Wedge at 0x209f2071450>,
# ...
#  [Text(-0.5536762623249643, 0.9504959739724612, 'Certified'),
#   Text(0.5536761188040589, -0.95049605757524, 'Denied')])

# %% [markdown]
# - Frequency table we did from scratch also with method
#     - **value_counts**
# - we selected a cta and num data types
#     - **select_dtypes**
# - we can select a single column or mutiple columns
#     - **series or df**
# - if any one give two list to you, you can able to create a dataframe
# - clear difference between
#     - dataframe
#     - series
#     - values  : **numpy format**

# %%
for i in cat[1:]:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    plt.figure(figsize=(10, 6))
    plt.pie(values,labels=keys)
    plt.xlabel('Lables')
    # plt.ylabel('Counts')
    plt.title(f'{i}_bar_chart')
    plt.savefig(f'{i}.jpg')
    plt.show()

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot(3,3,1)
plt.subplot(3,3,2)

for i in range(len(cat[1:])):
    plt.subplot(3,3,i+1)

# %%
for i,j in enumerate(cat[1:]):
    print(i,j)
# Out:
# 0 continent
# 1 education_of_employee
# 2 has_job_experience
# 3 requires_job_training
# 4 region_of_employment
# 5 unit_of_wage
# 6 full_time_position
# 7 case_status

# %%
plt.figure(figsize=(22, 14))
for i,j in enumerate(cat[1:]):
    keys=visa_df[j].value_counts().keys()
    values=visa_df[j].value_counts().values
    plt.subplot(3,3,i+1)
    plt.bar(keys,values)
    plt.xlabel('Lables')
    plt.ylabel('Counts')
    plt.title(f'{j}_bar_chart')
    plt.savefig(f'{j}.jpg')
#plt.show()
